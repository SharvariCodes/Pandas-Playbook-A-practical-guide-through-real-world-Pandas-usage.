# %%
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df1=pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ## **Display top 3 rows of the dataset**

# %%
df1.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# ## **Display last 3 rows of the dataset**

# %%
df1.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ## **Find the shape of our dataset (number of rows and columns)**

# %%
df1.shape
# Out:
# (7, 3)

# %% [markdown]
# ## **Get information about the datset like total number of rows, total columns, datatypes of each column and memory requirement**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %% [markdown]
# ## **Check Null values in the Dataset**

# %%
df1.isnull().sum(axis=0)
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
df1.isna()
# Out:
#     Name  Marks  Gender
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False

# %% [markdown]
# ## **Get the overall statistics of the dataframe**

# %%
df1.describe(include='all')
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %% [markdown]
# ## **Find unique values from the gender column**

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ## **Find the Number of unique values from the gender column**

# %%
df1['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# ## **Count of unique values in Gender Column**

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# ## **Find total number of students having marks between 90 to 100 (inclusive) using between method**

# %%
df1[df1['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
df1[(df1['Marks']>=90) & (df1['Marks']<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
len(df1[(df1['Marks']>=90) & (df1['Marks']<=100)])
# Out:
# 4

# %%
sum(df1['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# ## **Find Average Marks**

# %%
float(round(df1['Marks'].mean(),ndigits=2))
# Out:
# 92.14

# %%
float(round(df1['Marks'].max(),ndigits=2))
# Out:
# 99.0

# %%
float(round(df1['Marks'].min(),ndigits=2))
# Out:
# 83.0

# %% [markdown]
# ## **Apply Method**

# %%
def marks(x):
    return x/10

# %%
df1['CGPA'] = df1['Marks'].apply(marks)

# %%
df1
# Out:
#       Name  Marks  Gender  CGPA
# 0  Priyang     98    Male   9.8
# 1   Aadhya     89  Female   8.9
# 2   Krisha     99  Female   9.9
# 3   Vedant     87    Male   8.7
# 4   Parshv     90    Male   9.0
# 5   Mittal     83  Female   8.3
# 6  Archana     99  Female   9.9

# %%
df1['Marks'].apply(lambda x:x/10)
# Out:
# 0    9.8
# 1    8.9
# 2    9.9
# 3    8.7
# 4    9.0
# 5    8.3
# 6    9.9
# Name: Marks, dtype: float64

# %%
df1['Name'].apply(lambda x:len(x))
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %% [markdown]
# ## **Map Function**

# %%
df1['Gender_Mapped'] = df1['Gender'].map({'Male':1, 'Female': 0})

# %%
df1['Gender_Mapped_dup'] = df1['Gender'].map({'Male':1, 'Female': 0})

# %%
df1['Gender_Mapped_dup_dup'] = df1['Gender'].map({'Male':1, 'Female': 0})

# %%
df1
# Out:
#       Name  Marks  Gender  CGPA  Gender_Mapped  Gender_Mapped_dup  \
# 0  Priyang     98    Male   9.8              1                  1
# 1   Aadhya     89  Female   8.9              0                  0
# 2   Krisha     99  Female   9.9              0                  0
# 3   Vedant     87    Male   8.7              1                  1
# 4   Parshv     90    Male   9.0              1                  1
# 5   Mittal     83  Female   8.3              0                  0
# 6  Archana     99  Female   9.9              0                  0
#
#    Gender_Mapped_dup_dup
# 0                      1
# 1                      0
# 2                      0
# 3                      1
# 4                      1
# 5                      0
# 6                      0

# %% [markdown]
# ## **Drop the column(s)**

# %%
df1.drop(['Gender_Mapped_dup', 'Gender_Mapped_dup_dup'], axis=1,inplace=True)

# %%
df1
# Out:
#       Name  Marks  Gender  CGPA  Gender_Mapped
# 0  Priyang     98    Male   9.8              1
# 1   Aadhya     89  Female   8.9              0
# 2   Krisha     99  Female   9.9              0
# 3   Vedant     87    Male   8.7              1
# 4   Parshv     90    Male   9.0              1
# 5   Mittal     83  Female   8.3              0
# 6  Archana     99  Female   9.9              0

# %% [markdown]
# ## **Print name of the columns**

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'CGPA', 'Gender_Mapped'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# ## **Sort the DataFrame as per the marks column**

# %%
df1.sort_values(by='Marks',ascending=False)
# Out:
#       Name  Marks  Gender  CGPA  Gender_Mapped
# 2   Krisha     99  Female   9.9              0
# 6  Archana     99  Female   9.9              0
# 0  Priyang     98    Male   9.8              1
# 4   Parshv     90    Male   9.0              1
# 1   Aadhya     89  Female   8.9              0
# 3   Vedant     87    Male   8.7              1
# 5   Mittal     83  Female   8.3              0

# %% [markdown]
# ## **Name and marks of the female students**

# %%
df1[df1['Gender']  == 'Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99

# %%
df1[df1['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99
